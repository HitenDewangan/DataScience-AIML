# %%
import numpy as np          # For numerical operations
import pandas as pd         # For data manipulation and analysis
import matplotlib.pyplot as plt  # For data visualization
import seaborn as sns       # For statistical data visualization

plt.style.use('classic')

# %%
data = pd.read_csv("./Downloads/listings_summary.csv")

# %%
data
# Out:
#              id     scrape_id last_scraped experiences_offered    host_id  \
# 0          2015  2.020000e+13   07-11-2018                none       2217
# 1          2695  2.020000e+13   07-11-2018                none       2986
# 2          3176  2.020000e+13   07-11-2018                none       3718
# 3          3309  2.020000e+13   07-11-2018                none       4108
# 4          7071  2.020000e+13   07-11-2018                none      17391
# ...         ...           ...          ...                 ...        ...
# 22547  29856708  2.020000e+13   07-11-2018                none   87555909
# 22548  29857108  2.020000e+13   07-11-2018                none   67537363
# 22549  29864272  2.020000e+13   07-11-2018                none    3146923
# 22550  29866805  2.020000e+13   07-11-2018                none   36961901
# 22551  29867352  2.020000e+13   07-11-2018                none  177464875
#
#         host_name  host_since                         host_location  \
# 0             Ian  18-08-2008  Key Biscayne, Florida, United States
# 1         Michael  16-09-2008               Berlin, Berlin, Germany
# 2          Britta  19-10-2008  Coledale, New South Wales, Australia
# 3            Jana  07-11-2008               Berlin, Berlin, Germany
# 4          Bright  16-05-2009               Berlin, Berlin, Germany
# ...           ...         ...                                   ...
# 22547     Ulisses  02-08-2016               Berlin, Berlin, Germany
# 22548        Jörg  17-04-2016               Berlin, Berlin, Germany
# 22549      Martin  03-08-2012               Berlin, Berlin, Germany
# 22550  Arte Luise  28-06-2015               Berlin, Berlin, Germany
# 22551   Sebastian  09-03-2018               Berlin, Berlin, Germany
#
#        host_response_time  host_response_rate  ...  review_scores_value  \
# 0          within an hour                0.96  ...                  9.0
# 1                     NaN                 NaN  ...                 10.0
# 2            within a day                1.00  ...                  9.0
# 3                     NaN                 NaN  ...                  9.0
# 4          within an hour                1.00  ...                  9.0
# ...                   ...                 ...  ...                  ...
# 22547                 NaN                 NaN  ...                  NaN
# 22548      within an hour                0.88  ...                  NaN
# 22549                 NaN                 NaN  ...                  NaN
# 22550  within a few hours                0.90  ...                  NaN
# 22551                 NaN                 NaN  ...                  NaN
#
#       requires_license jurisdiction_names  instant_bookable  \
# 0                    t                NaN                 f
# 1                    t                NaN                 f
# 2                    t                NaN                 t
# 3                    t                NaN                 f
# 4                    t                NaN                 f
# ...                ...                ...               ...
# 22547                t                NaN                 f
# 22548                t                NaN                 t
# 22549                t                NaN                 f
# 22550                t                NaN                 f
# 22551                t                NaN                 f
#
#        is_business_travel_ready          cancellation_policy  \
# 0                             f  strict_14_with_grace_period
# 1                             f                     flexible
# 2                             f  strict_14_with_grace_period
# 3                             f  strict_14_with_grace_period
# 4                             f                     moderate
# ...                         ...                          ...
# 22547                         f                     flexible
# 22548                         f                     flexible
# 22549                         f                     flexible
# 22550                         f                     flexible
# 22551                         f                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 0                                 f                                f
# 1                                 f                                f
# 2                                 f                                f
# 3                                 f                                f
# 4                                 f                                f
# ...                             ...                              ...
# 22547                             f                                f
# 22548                             f                                f
# 22549                             f                                f
# 22550                             f                                f
# 22551                             f                                f
#
#       calculated_host_listings_count reviews_per_month
# 0                                  4              3.76
# 1                                  1              1.42
# 2                                  1              1.25
# 3                                  1              0.39
# 4                                  1              1.75
# ...                              ...               ...
# 22547                              1               NaN
# 22548                              6               NaN
# 22549                              2               NaN
# 22550                              3               NaN
# 22551                              1               NaN
#
# [22552 rows x 76 columns]

# %%
data.head()
# Out:
#      id     scrape_id last_scraped experiences_offered  host_id host_name  \
# 0  2015  2.020000e+13   07-11-2018                none     2217       Ian
# 1  2695  2.020000e+13   07-11-2018                none     2986   Michael
# 2  3176  2.020000e+13   07-11-2018                none     3718    Britta
# 3  3309  2.020000e+13   07-11-2018                none     4108      Jana
# 4  7071  2.020000e+13   07-11-2018                none    17391    Bright
#
#    host_since                         host_location host_response_time  \
# 0  18-08-2008  Key Biscayne, Florida, United States     within an hour
# 1  16-09-2008               Berlin, Berlin, Germany                NaN
# 2  19-10-2008  Coledale, New South Wales, Australia       within a day
# 3  07-11-2008               Berlin, Berlin, Germany                NaN
# 4  16-05-2009               Berlin, Berlin, Germany     within an hour
#
#    host_response_rate  ...  review_scores_value requires_license  \
# 0                0.96  ...                  9.0                t
# 1                 NaN  ...                 10.0                t
# 2                1.00  ...                  9.0                t
# 3                 NaN  ...                  9.0                t
# 4                1.00  ...                  9.0                t
#
#   jurisdiction_names  instant_bookable  is_business_travel_ready  \
# 0                NaN                 f                         f
# 1                NaN                 f                         f
# 2                NaN                 t                         f
# 3                NaN                 f                         f
# 4                NaN                 f                         f
#
#            cancellation_policy require_guest_profile_picture  \
# 0  strict_14_with_grace_period                             f
# 1                     flexible                             f
# 2  strict_14_with_grace_period                             f
# 3  strict_14_with_grace_period                             f
# 4                     moderate                             f
#
#   require_guest_phone_verification calculated_host_listings_count  \
# 0                                f                              4
# 1                                f                              1
# 2                                f                              1
# 3                                f                              1
# 4                                f                              1
#
#   reviews_per_month
# 0              3.76
# 1              1.42
# 2              1.25
# 3              0.39
# 4              1.75
#
# [5 rows x 76 columns]

# %%
df =data

# %%
df.shape
# Out:
# (22552, 76)

# %% [markdown]
# # NULL VALUE TREATMENT

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# jurisdiction_names      22552
# host_acceptance_rate    22552
# square_feet             22106
# monthly_price           19893
# weekly_price            18871
#                         ...
# price                       0
# guests_included             0
# extra_people                0
# minimum_nights              0
# bed_type                    0
# Length: 76, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 198383

# %%
round(df.isnull().sum().sort_values(ascending=False)*100/df.isnull().sum().sum(), 0)
# Out:
# jurisdiction_names      11.0
# host_acceptance_rate    11.0
# square_feet             11.0
# monthly_price           10.0
# weekly_price            10.0
#                         ...
# price                    0.0
# guests_included          0.0
# extra_people             0.0
# minimum_nights           0.0
# bed_type                 0.0
# Length: 76, dtype: float64

# %%
pd.set_option('display.min_rows', None)
# pd.reset_option('display.min_rows')

# %%
round(df.isnull().sum().sort_values(ascending=False)*100/df.shape[0], 0)
# Out:
# jurisdiction_names              100.0
# host_acceptance_rate            100.0
# square_feet                      98.0
# monthly_price                    88.0
# weekly_price                     84.0
# host_response_rate               57.0
# host_response_time               57.0
# security_deposit                 42.0
# cleaning_fee                     32.0
# host_neighbourhood               23.0
# review_scores_value              20.0
# review_scores_checkin            20.0
# review_scores_location           20.0
# review_scores_communication      20.0
# review_scores_accuracy           20.0
# review_scores_cleanliness        20.0
# review_scores_rating             19.0
# reviews_per_month                17.0
# first_review                     17.0
# last_review                      17.0
# neighbourhood                     5.0
# zipcode                           3.0
# host_location                     1.0
# state                             0.0
# market                            0.0
# beds                              0.0
# bathrooms                         0.0
# host_listings_count               0.0
# host_has_profile_pic              0.0
# host_since                        0.0
#                                 ...
# cancellation_policy               0.0
# is_business_travel_ready          0.0
# instant_bookable                  0.0
# requires_license                  0.0
# availability_30                   0.0
# id                                0.0
# calendar_updated                  0.0
# maximum_nights                    0.0
# last_scraped                      0.0
# experiences_offered               0.0
# host_id                           0.0
# street                            0.0
# neighbourhood_cleansed            0.0
# neighbourhood_group_cleansed      0.0
# smart_location                    0.0
# country_code                      0.0
# country                           0.0
# latitude                          0.0
# longitude                         0.0
# is_location_exact                 0.0
# property_type                     0.0
# room_type                         0.0
# accommodates                      0.0
# scrape_id                         0.0
# amenities                         0.0
# price                             0.0
# guests_included                   0.0
# extra_people                      0.0
# minimum_nights                    0.0
# bed_type                          0.0
# Length: 76, dtype: float64

# %% [markdown]
# ***

# %% [markdown]
# #### Dropping High Null Values Columns

# %%
copy_data = df.copy()

# %%
copy_data.drop(columns=['square_feet', 'monthly_price', 'weekly_price', 'host_response_rate', 'host_response_time'], axis=1, inplace=True)

# %%
copy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 71 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                22552 non-null  int64
#  1   scrape_id                         22552 non-null  float64
#  2   last_scraped                      22552 non-null  object
#  3   experiences_offered               22552 non-null  object
#  4   host_id                           22552 non-null  int64
#  5   host_name                         22526 non-null  object
#  6   host_since                        22526 non-null  object
#  7   host_location                     22436 non-null  object
#  8   host_acceptance_rate              0 non-null      float64
#  9   host_is_superhost                 22526 non-null  object
#  10  host_neighbourhood                17458 non-null  object
#  11  host_listings_count               22526 non-null  float64
#  12  host_total_listings_count         22526 non-null  float64
#  13  host_verifications                22526 non-null  object
#  14  host_has_profile_pic              22526 non-null  object
#  15  host_identity_verified            22526 non-null  object
#  16  street                            22552 non-null  object
#  17  neighbourhood                     21421 non-null  object
#  18  neighbourhood_cleansed            22552 non-null  object
#  19  neighbourhood_group_cleansed      22552 non-null  object
#  20  city                              22547 non-null  object
#  21  state                             22468 non-null  object
#  22  zipcode                           21896 non-null  object
#  23  market                            22489 non-null  object
#  24  smart_location                    22552 non-null  object
#  25  country_code                      22552 non-null  object
#  26  country                           22552 non-null  object
#  27  latitude                          22552 non-null  float64
#  28  longitude                         22552 non-null  float64
#  29  is_location_exact                 22552 non-null  object
#  30  property_type                     22552 non-null  object
#  31  room_type                         22552 non-null  object
#  32  accommodates                      22552 non-null  int64
#  33  bathrooms                         22520 non-null  float64
#  34  bedrooms                          22534 non-null  float64
#  35  beds                              22512 non-null  float64
#  36  bed_type                          22552 non-null  object
#  37  amenities                         22552 non-null  object
#  38  price                             22552 non-null  object
#  39  security_deposit                  13191 non-null  object
#  40  cleaning_fee                      15406 non-null  object
#  41  guests_included                   22552 non-null  int64
#  42  extra_people                      22552 non-null  object
#  43  minimum_nights                    22552 non-null  int64
#  44  maximum_nights                    22552 non-null  int64
#  45  calendar_updated                  22552 non-null  object
#  46  has_availability                  22552 non-null  object
#  47  availability_30                   22552 non-null  int64
#  48  availability_60                   22552 non-null  int64
#  49  availability_90                   22552 non-null  int64
#  50  availability_365                  22552 non-null  int64
#  51  calendar_last_scraped             22552 non-null  int64
#  52  number_of_reviews                 22552 non-null  int64
#  53  first_review                      18638 non-null  float64
#  54  last_review                       18644 non-null  float64
#  55  review_scores_rating              18163 non-null  float64
#  56  review_scores_accuracy            18138 non-null  float64
#  57  review_scores_cleanliness         18141 non-null  float64
#  58  review_scores_checkin             18120 non-null  float64
#  59  review_scores_communication       18134 non-null  float64
#  60  review_scores_location            18121 non-null  float64
#  61  review_scores_value               18117 non-null  float64
#  62  requires_license                  22552 non-null  object
#  63  jurisdiction_names                0 non-null      float64
#  64  instant_bookable                  22552 non-null  object
#  65  is_business_travel_ready          22552 non-null  object
#  66  cancellation_policy               22552 non-null  object
#  67  require_guest_profile_picture     22552 non-null  object
#  68  require_guest_phone_verification  22552 non-null  object
#  69  calculated_host_listings_count    22552 non-null  int64
#  70  reviews_per_month                 18638 non-null  float64
# dtypes: float64(20), int64(13), object(38)
# memory usage: 12.2+ MB

# %%
copy_data.drop(columns=['host_id', 'host_name', 'host_is_superhost', 'scrape_id', 'last_scraped', 'country_code', 'country', 'id', 'calendar_last_scraped'], axis=1, inplace=True)

# %%
copy_data.shape
# Out:
# (22552, 62)

# %%
copy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 62 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   experiences_offered               22552 non-null  object
#  1   host_since                        22526 non-null  object
#  2   host_location                     22436 non-null  object
#  3   host_acceptance_rate              0 non-null      float64
#  4   host_neighbourhood                17458 non-null  object
#  5   host_listings_count               22526 non-null  float64
#  6   host_total_listings_count         22526 non-null  float64
#  7   host_verifications                22526 non-null  object
#  8   host_has_profile_pic              22526 non-null  object
#  9   host_identity_verified            22526 non-null  object
#  10  street                            22552 non-null  object
#  11  neighbourhood                     21421 non-null  object
#  12  neighbourhood_cleansed            22552 non-null  object
#  13  neighbourhood_group_cleansed      22552 non-null  object
#  14  city                              22547 non-null  object
#  15  state                             22468 non-null  object
#  16  zipcode                           21896 non-null  object
#  17  market                            22489 non-null  object
#  18  smart_location                    22552 non-null  object
#  19  latitude                          22552 non-null  float64
#  20  longitude                         22552 non-null  float64
#  21  is_location_exact                 22552 non-null  object
#  22  property_type                     22552 non-null  object
#  23  room_type                         22552 non-null  object
#  24  accommodates                      22552 non-null  int64
#  25  bathrooms                         22520 non-null  float64
#  26  bedrooms                          22534 non-null  float64
#  27  beds                              22512 non-null  float64
#  28  bed_type                          22552 non-null  object
#  29  amenities                         22552 non-null  object
#  30  price                             22552 non-null  object
#  31  security_deposit                  13191 non-null  object
#  32  cleaning_fee                      15406 non-null  object
#  33  guests_included                   22552 non-null  int64
#  34  extra_people                      22552 non-null  object
#  35  minimum_nights                    22552 non-null  int64
#  36  maximum_nights                    22552 non-null  int64
#  37  calendar_updated                  22552 non-null  object
#  38  has_availability                  22552 non-null  object
#  39  availability_30                   22552 non-null  int64
#  40  availability_60                   22552 non-null  int64
#  41  availability_90                   22552 non-null  int64
#  42  availability_365                  22552 non-null  int64
#  43  number_of_reviews                 22552 non-null  int64
#  44  first_review                      18638 non-null  float64
#  45  last_review                       18644 non-null  float64
#  46  review_scores_rating              18163 non-null  float64
#  47  review_scores_accuracy            18138 non-null  float64
#  48  review_scores_cleanliness         18141 non-null  float64
#  49  review_scores_checkin             18120 non-null  float64
#  50  review_scores_communication       18134 non-null  float64
#  51  review_scores_location            18121 non-null  float64
#  52  review_scores_value               18117 non-null  float64
#  53  requires_license                  22552 non-null  object
#  54  jurisdiction_names                0 non-null      float64
#  55  instant_bookable                  22552 non-null  object
#  56  is_business_travel_ready          22552 non-null  object
#  57  cancellation_policy               22552 non-null  object
#  58  require_guest_profile_picture     22552 non-null  object
#  59  require_guest_phone_verification  22552 non-null  object
#  60  calculated_host_listings_count    22552 non-null  int64
#  61  reviews_per_month                 18638 non-null  float64
# dtypes: float64(19), int64(10), object(33)
# memory usage: 10.7+ MB

# %%
df.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'experiences_offered', 'host_id',
#        'host_name', 'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_acceptance_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'square_feet',
#        'price', 'weekly_price', 'monthly_price', 'security_deposit',
#        'cleaning_fee', 'guests_included', 'extra_people', 'minimum_nights',
#        'maximum_nights', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready',
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %% [markdown]
# ### null value treatment

# %% [markdown]
# #### Step1 : find null values column wise
# #### Step2 : remove all columns with null values > 50%
# #### Step3 : separate numerical & categorical variables
# #### Step4 : Impute Num & Categorical variable columns - Central Tendency / Predictive KNN respectively

# %%
copy_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 62 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   experiences_offered               22552 non-null  object
#  1   host_since                        22526 non-null  object
#  2   host_location                     22436 non-null  object
#  3   host_acceptance_rate              0 non-null      float64
#  4   host_neighbourhood                17458 non-null  object
#  5   host_listings_count               22526 non-null  float64
#  6   host_total_listings_count         22526 non-null  float64
#  7   host_verifications                22526 non-null  object
#  8   host_has_profile_pic              22526 non-null  object
#  9   host_identity_verified            22526 non-null  object
#  10  street                            22552 non-null  object
#  11  neighbourhood                     21421 non-null  object
#  12  neighbourhood_cleansed            22552 non-null  object
#  13  neighbourhood_group_cleansed      22552 non-null  object
#  14  city                              22547 non-null  object
#  15  state                             22468 non-null  object
#  16  zipcode                           21896 non-null  object
#  17  market                            22489 non-null  object
#  18  smart_location                    22552 non-null  object
#  19  latitude                          22552 non-null  float64
#  20  longitude                         22552 non-null  float64
#  21  is_location_exact                 22552 non-null  object
#  22  property_type                     22552 non-null  object
#  23  room_type                         22552 non-null  object
#  24  accommodates                      22552 non-null  int64
#  25  bathrooms                         22520 non-null  float64
#  26  bedrooms                          22534 non-null  float64
#  27  beds                              22512 non-null  float64
#  28  bed_type                          22552 non-null  object
#  29  amenities                         22552 non-null  object
#  30  price                             22552 non-null  object
#  31  security_deposit                  13191 non-null  object
#  32  cleaning_fee                      15406 non-null  object
#  33  guests_included                   22552 non-null  int64
#  34  extra_people                      22552 non-null  object
#  35  minimum_nights                    22552 non-null  int64
#  36  maximum_nights                    22552 non-null  int64
#  37  calendar_updated                  22552 non-null  object
#  38  has_availability                  22552 non-null  object
#  39  availability_30                   22552 non-null  int64
#  40  availability_60                   22552 non-null  int64
#  41  availability_90                   22552 non-null  int64
#  42  availability_365                  22552 non-null  int64
#  43  number_of_reviews                 22552 non-null  int64
#  44  first_review                      18638 non-null  float64
#  45  last_review                       18644 non-null  float64
#  46  review_scores_rating              18163 non-null  float64
#  47  review_scores_accuracy            18138 non-null  float64
#  48  review_scores_cleanliness         18141 non-null  float64
#  49  review_scores_checkin             18120 non-null  float64
#  50  review_scores_communication       18134 non-null  float64
#  51  review_scores_location            18121 non-null  float64
#  52  review_scores_value               18117 non-null  float64
#  53  requires_license                  22552 non-null  object
#  54  jurisdiction_names                0 non-null      float64
#  55  instant_bookable                  22552 non-null  object
#  56  is_business_travel_ready          22552 non-null  object
#  57  cancellation_policy               22552 non-null  object
#  58  require_guest_profile_picture     22552 non-null  object
#  59  require_guest_phone_verification  22552 non-null  object
#  60  calculated_host_listings_count    22552 non-null  int64
#  61  reviews_per_month                 18638 non-null  float64
# dtypes: float64(19), int64(10), object(33)
# memory usage: 10.7+ MB

# %% [markdown]
# ##### Columns having wrong datatype
# price, extra_people, security, deposit, cleaning_fee

# %%
copy_data.drop(columns = ['experiences_offered','has_availability'], axis=1, inplace = True)  #removing cols having no need
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 copy_data.drop(columns = ['experiences_offered','has_availability'], axis=1, inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['experiences_offered', 'has_availability'] not found in axis"

# %%
copy_data.has_availability.unique()

# %%
copy_data.price = copy_data.price.apply(lambda x : x.replace("$", ""))   #remove dollar sign
copy_data['price'] = copy_data['price'].str.replace("$", "")

# %%
#similarly do for other cols
cols_to_treat = ['price','extra_people', 'security_deposit', 'cleaning_fee']

for i in cols_to_treat:
    # Remove '$' from the specified columns
    copy_data[i] = copy_data[i].astype(str).str.replace("$", "")
    
    # Convert the columns to int64 or float64
    copy_data[i] = pd.to_numeric(copy_data[i], errors='coerce')  # Convert to numeric, handling potential errors
    copy_data[i] = copy_data[i].astype('float64')  # Convert to Int64 to handle missing values

# Now the specified columns in 'copy_data' are of type Int64 / float64

# %%
copy_data[cols_to_treat].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22552 entries, 0 to 22551
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             22511 non-null  float64
#  1   extra_people      22552 non-null  float64
#  2   security_deposit  12653 non-null  float64
#  3   cleaning_fee      15405 non-null  float64
# dtypes: float64(4)
# memory usage: 704.9 KB

# %%
Num = []
Cat = []

# %%
for col in copy_data.columns:
    if df[col].dtype == 'object':
        Cat.append(col)
    else:
        Num.append(col)

# %%
len(Num)
# Out:
# 27

# %%
Num
# Out:
# ['host_listings_count',
#  'host_total_listings_count',
#  'latitude',
#  'longitude',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'guests_included',
#  'minimum_nights',
#  'maximum_nights',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'number_of_reviews',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'calculated_host_listings_count',
#  'reviews_per_month']

# %%
copy_data['jurisdiction_names']
# Out:
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      NaN
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
#          ..
# 22522   NaN
# 22523   NaN
# 22524   NaN
# 22525   NaN
# 22526   NaN
# 22527   NaN
# 22528   NaN
# 22529   NaN
# 22530   NaN
# 22531   NaN
# 22532   NaN
# 22533   NaN
# 22534   NaN
# 22535   NaN
# 22536   NaN
# 22537   NaN
# 22538   NaN
# 22539   NaN
# 22540   NaN
# 22541   NaN
# 22542   NaN
# 22543   NaN
# 22544   NaN
# 22545   NaN
# 22546   NaN
# 22547   NaN
# 22548   NaN
# 22549   NaN
# 22550   NaN
# 22551   NaN
# Name: jurisdiction_names, Length: 22552, dtype: float64

# %%
len(Cat)
# Out:
# 31

# %%
Cat
# Out:
# ['host_since',
#  'host_location',
#  'host_neighbourhood',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'bed_type',
#  'amenities',
#  'price',
#  'security_deposit',
#  'cleaning_fee',
#  'extra_people',
#  'calendar_updated',
#  'requires_license',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification']

# %%
copy_data[['price','security_deposit', 'cleaning_fee', 'extra_people']]
# Out:
#        price  security_deposit  cleaning_fee  extra_people
# 0       60.0             200.0          30.0          28.0
# 1       17.0               0.0           0.0           0.0
# 2       90.0             200.0          50.0          20.0
# 3       26.0             250.0          30.0          18.0
# 4       42.0               0.0           0.0          24.0
# 5      180.0             400.0          80.0          10.0
# 6       70.0             500.0           0.0           0.0
# 7      120.0               NaN           NaN          13.0
# 8       90.0             500.0          50.0          20.0
# 9       45.0               0.0          18.0          26.0
# 10      49.0               0.0          50.0          15.0
# 11     129.0             500.0          49.0          24.0
# 12      70.0             500.0          40.0          18.0
# 13      98.0             300.0          50.0          25.0
# 14     160.0             150.0          40.0          35.0
# 15      65.0             500.0          50.0           0.0
# 16      90.0             200.0          35.0           5.0
# 17      90.0             200.0          55.0           5.0
# 18     197.0             250.0          50.0          40.0
# 19      70.0               NaN           NaN           0.0
# 20      90.0             200.0          50.0          20.0
# 21      60.0               NaN          30.0          10.0
# 22     130.0               NaN          80.0           0.0
# 23     100.0               NaN          40.0          20.0
# 24      44.0             100.0          15.0          15.0
# 25      62.0               0.0          20.0           8.0
# 26      55.0               NaN          50.0          10.0
# 27      40.0             500.0           5.0          20.0
# 28      25.0               0.0           0.0          15.0
# 29      52.0             100.0          30.0          12.0
# ...      ...               ...           ...           ...
# 22522   45.0               0.0          30.0          36.0
# 22523  150.0             150.0          30.0           0.0
# 22524   30.0             200.0          25.0          10.0
# 22525   30.0               NaN           NaN           0.0
# 22526  599.0               0.0           0.0           0.0
# 22527  399.0               0.0          49.0           0.0
# 22528  100.0               NaN           NaN           0.0
# 22529   35.0               NaN           NaN           0.0
# 22530  105.0               0.0          60.0          15.0
# 22531   95.0               NaN           NaN           0.0
# 22532   70.0               NaN         299.0           0.0
# 22533   30.0               NaN           NaN           0.0
# 22534   26.0               NaN           NaN           0.0
# 22535   21.0               NaN           NaN           0.0
# 22536  150.0               NaN           NaN           0.0
# 22537   23.0               NaN           NaN           0.0
# 22538   60.0               NaN           NaN           0.0
# 22539   30.0               NaN           NaN           0.0
# 22540   30.0               NaN           NaN           0.0
# 22541   19.0               0.0           0.0          10.0
# 22542   40.0               NaN           NaN           0.0
# 22543   29.0               NaN           NaN           0.0
# 22544   90.0             100.0          20.0           0.0
# 22545   39.0               0.0          10.0          10.0
# 22546  100.0               NaN         100.0           0.0
# 22547   60.0               NaN           NaN           0.0
# 22548   20.0               0.0           0.0          10.0
# 22549   85.0               NaN           NaN           0.0
# 22550   99.0               NaN           NaN           0.0
# 22551   45.0               NaN           NaN           0.0
#
# [22552 rows x 4 columns]

# %%
copy_data.shape
# Out:
# (22552, 60)

# %%
copy_data[Num]
# Out:
#        host_acceptance_rate  host_listings_count  host_total_listings_count  \
# 0                       NaN                  4.0                        4.0
# 1                       NaN                  1.0                        1.0
# 2                       NaN                  1.0                        1.0
# 3                       NaN                  1.0                        1.0
# 4                       NaN                  1.0                        1.0
# 5                       NaN                  1.0                        1.0
# 6                       NaN                  3.0                        3.0
# 7                       NaN                  1.0                        1.0
# 8                       NaN                  4.0                        4.0
# 9                       NaN                  1.0                        1.0
# 10                      NaN                  2.0                        2.0
# 11                      NaN                  1.0                        1.0
# 12                      NaN                  4.0                        4.0
# 13                      NaN                  2.0                        2.0
# 14                      NaN                  1.0                        1.0
# 15                      NaN                  1.0                        1.0
# 16                      NaN                  2.0                        2.0
# 17                      NaN                  2.0                        2.0
# 18                      NaN                  2.0                        2.0
# 19                      NaN                  3.0                        3.0
# 20                      NaN                  1.0                        1.0
# 21                      NaN                 12.0                       12.0
# 22                      NaN                  3.0                        3.0
# 23                      NaN                  4.0                        4.0
# 24                      NaN                  1.0                        1.0
# 25                      NaN                  1.0                        1.0
# 26                      NaN                  1.0                        1.0
# 27                      NaN                  2.0                        2.0
# 28                      NaN                  1.0                        1.0
# 29                      NaN                  2.0                        2.0
# ...                     ...                  ...                        ...
# 22522                   NaN                  1.0                        1.0
# 22523                   NaN                  1.0                        1.0
# 22524                   NaN                  1.0                        1.0
# 22525                   NaN                  1.0                        1.0
# 22526                   NaN                  3.0                        3.0
# 22527                   NaN                  3.0                        3.0
# 22528                   NaN                  1.0                        1.0
# 22529                   NaN                  3.0                        3.0
# 22530                   NaN                  3.0                        3.0
# 22531                   NaN                  1.0                        1.0
# 22532                   NaN                  9.0                        9.0
# 22533                   NaN                  1.0                        1.0
# 22534                   NaN                  5.0                        5.0
# 22535                   NaN                  5.0                        5.0
# 22536                   NaN                  2.0                        2.0
# 22537                   NaN                  5.0                        5.0
# 22538                   NaN                  1.0                        1.0
# 22539                   NaN                  1.0                        1.0
# 22540                   NaN                  1.0                        1.0
# 22541                   NaN                  2.0                        2.0
# 22542                   NaN                  1.0                        1.0
# 22543                   NaN                  1.0                        1.0
# 22544                   NaN                  1.0                        1.0
# 22545                   NaN                  1.0                        1.0
# 22546                   NaN                  1.0                        1.0
# 22547                   NaN                  1.0                        1.0
# 22548                   NaN                  6.0                        6.0
# 22549                   NaN                  3.0                        3.0
# 22550                   NaN                  3.0                        3.0
# 22551                   NaN                  1.0                        1.0
#
#         latitude  longitude  accommodates  bathrooms  bedrooms  beds  \
# 0      52.534537  13.402557             3        1.0       1.0   2.0
# 1      52.548513  13.404553             2        1.0       1.0   1.0
# 2      52.534996  13.417579             4        1.0       1.0   2.0
# 3      52.498855  13.349065             2        1.0       1.0   1.0
# 4      52.543157  13.415091             2        1.0       1.0   2.0
# 5      52.533031  13.416047             7        2.5       4.0   7.0
# 6      52.547846  13.405562             2        1.0       0.0   1.0
# 7      52.510514  13.457850             2        1.0       1.0   2.0
# 8      52.504792  13.435102             5        1.0       1.0   3.0
# 9      52.529071  13.412843             2        1.0       1.0   1.0
# 10     52.495476  13.421821             2        1.0       NaN   1.0
# 11     52.536952  13.407615             4        1.0       2.0   2.0
# 12     52.502733  13.434620             4        1.0       1.0   2.0
# 13     52.494851  13.428501             4        1.0       2.0   2.0
# 14     52.534348  13.405577             5        1.0       1.0   4.0
# 15     52.489714  13.379748             4        1.0       1.0   4.0
# 16     52.530791  13.418084             4        2.5       2.0   2.0
# 17     52.530259  13.419467             4        2.5       2.0   2.0
# 18     52.544062  13.421377             8        2.0       2.0   8.0
# 19     52.546719  13.405117             2        1.0       0.0   1.0
# 20     52.513385  13.469948             6        1.0       2.0   4.0
# 21     52.486106  13.434817             3        NaN       1.0   NaN
# 22     52.541788  13.423883             4        1.0       2.0   3.0
# 23     52.545967  13.422359             8        1.0       2.0   4.0
# 24     52.543089  13.422453             1        1.0       1.0   1.0
# 25     52.521418  13.357082             4        1.0       1.0   2.0
# 26     52.549361  13.418228             2        1.0       1.0   1.0
# 27     52.519677  13.302089             1        0.0       1.0   1.0
# 28     52.493389  13.364813             1        1.0       1.0   1.0
# 29     52.538220  13.404625             2        1.0       1.0   2.0
# ...          ...        ...           ...        ...       ...   ...
# 22522  52.491236  13.330882             2        1.0       1.0   1.0
# 22523  52.513255  13.318309             2        1.0       0.0   1.0
# 22524  52.504231  13.420850             2        0.5       1.0   1.0
# 22525  52.440587  13.353266             2        1.0       1.0   1.0
# 22526  52.494753  13.344451             4        1.0       1.0   2.0
# 22527  52.494714  13.344555             5        1.0       1.0   1.0
# 22528  52.491119  13.426435             2        1.0       0.0   1.0
# 22529  52.484395  13.357489             2        1.0       1.0   1.0
# 22530  52.485467  13.438652             4        3.0       2.0   2.0
# 22531  52.522064  13.418118             2        1.0       1.0   1.0
# 22532  52.514998  13.496708             2        1.0       0.0   1.0
# 22533  52.535236  13.437477             4        1.0       2.0   4.0
# 22534  52.569657  13.420882             2        1.0       1.0   1.0
# 22535  52.569500  13.422632             1        1.0       1.0   1.0
# 22536  52.536666  13.411360             4        1.0       2.0   2.0
# 22537  52.569261  13.422296             1        1.0       1.0   1.0
# 22538  52.496963  13.420962             2        1.0       0.0   1.0
# 22539  52.508844  13.273118             1        1.0       0.0   2.0
# 22540  52.497266  13.464208             2        1.0       1.0   1.0
# 22541  52.478012  13.448766             2        1.0       1.0   1.0
# 22542  52.470724  13.323199             2        1.0       1.0   1.0
# 22543  52.469517  13.442539             1        1.0       1.0   1.0
# 22544  52.515574  13.456987             4        1.0       2.0   2.0
# 22545  52.508700  13.445511             4        1.0       1.0   2.0
# 22546  52.488700  13.354795             4        1.0       2.0   2.0
# 22547  52.533865  13.400731             2        1.0       1.0   1.0
# 22548  52.496211  13.341738             6        1.0       1.0   4.0
# 22549  52.531800  13.411999             2        1.0       0.0   1.0
# 22550  52.520802  13.378688             2        1.0       1.0   1.0
# 22551  52.473762  13.424447             2        1.0       1.0   1.0
#
#        guests_included  ...  review_scores_rating  review_scores_accuracy  \
# 0                    1  ...                  93.0                    10.0
# 1                    1  ...                 100.0                    10.0
# 2                    2  ...                  92.0                     9.0
# 3                    1  ...                  88.0                     9.0
# 4                    1  ...                  96.0                    10.0
# 5                    5  ...                 100.0                    10.0
# 6                    1  ...                  93.0                    10.0
# 7                    1  ...                   NaN                     NaN
# 8                    2  ...                  94.0                    10.0
# 9                    1  ...                  96.0                    10.0
# 10                   1  ...                  96.0                    10.0
# 11                   2  ...                  87.0                     9.0
# 12                   2  ...                  95.0                     9.0
# 13                   2  ...                  94.0                    10.0
# 14                   4  ...                  94.0                     9.0
# 15                   1  ...                  87.0                     9.0
# 16                   2  ...                  94.0                    10.0
# 17                   2  ...                 100.0                    10.0
# 18                   4  ...                  91.0                     9.0
# 19                   1  ...                  92.0                     9.0
# 20                   4  ...                  91.0                     9.0
# 21                   2  ...                 100.0                    10.0
# 22                   2  ...                  96.0                    10.0
# 23                   4  ...                  95.0                    10.0
# 24                   1  ...                  89.0                     9.0
# 25                   2  ...                  89.0                     9.0
# 26                   1  ...                   NaN                     NaN
# 27                   1  ...                  88.0                     9.0
# 28                   1  ...                  91.0                    10.0
# 29                   1  ...                  95.0                    10.0
# ...                ...  ...                   ...                     ...
# 22522                1  ...                   NaN                     NaN
# 22523                2  ...                   NaN                     NaN
# 22524                1  ...                   NaN                     NaN
# 22525                1  ...                   NaN                     NaN
# 22526                2  ...                   NaN                     NaN
# 22527                2  ...                   NaN                     NaN
# 22528                1  ...                   NaN                     NaN
# 22529                1  ...                   NaN                     NaN
# 22530                1  ...                   NaN                     NaN
# 22531                1  ...                   NaN                     NaN
# 22532                1  ...                   NaN                     NaN
# 22533                1  ...                   NaN                     NaN
# 22534                1  ...                   NaN                     NaN
# 22535                1  ...                   NaN                     NaN
# 22536                1  ...                   NaN                     NaN
# 22537                1  ...                   NaN                     NaN
# 22538                1  ...                   NaN                     NaN
# 22539                1  ...                   NaN                     NaN
# 22540                1  ...                   NaN                     NaN
# 22541                1  ...                   NaN                     NaN
# 22542                1  ...                   NaN                     NaN
# 22543                1  ...                   NaN                     NaN
# 22544                1  ...                   NaN                     NaN
# 22545                1  ...                   NaN                     NaN
# 22546                1  ...                   NaN                     NaN
# 22547                1  ...                   NaN                     NaN
# 22548                1  ...                   NaN                     NaN
# 22549                1  ...                   NaN                     NaN
# 22550                1  ...                   NaN                     NaN
# 22551                1  ...                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 0                            9.0                   10.0
# 1                           10.0                   10.0
# 2                            9.0                    9.0
# 3                            9.0                    9.0
# 4                           10.0                   10.0
# 5                           10.0                   10.0
# 6                           10.0                    9.0
# 7                            NaN                    NaN
# 8                           10.0                   10.0
# 9                           10.0                   10.0
# 10                           9.0                   10.0
# 11                           9.0                    9.0
# 12                          10.0                   10.0
# 13                           9.0                   10.0
# 14                           9.0                   10.0
# 15                           9.0                    9.0
# 16                          10.0                   10.0
# 17                          10.0                   10.0
# 18                           9.0                    9.0
# 19                          10.0                   10.0
# 20                          10.0                    8.0
# 21                          10.0                   10.0
# 22                          10.0                   10.0
# 23                          10.0                   10.0
# 24                           9.0                   10.0
# 25                           9.0                    9.0
# 26                           NaN                    NaN
# 27                           9.0                   10.0
# 28                           9.0                   10.0
# 29                          10.0                   10.0
# ...                          ...                    ...
# 22522                        NaN                    NaN
# 22523                        NaN                    NaN
# 22524                        NaN                    NaN
# 22525                        NaN                    NaN
# 22526                        NaN                    NaN
# 22527                        NaN                    NaN
# 22528                        NaN                    NaN
# 22529                        NaN                    NaN
# 22530                        NaN                    NaN
# 22531                        NaN                    NaN
# 22532                        NaN                    NaN
# 22533                        NaN                    NaN
# 22534                        NaN                    NaN
# 22535                        NaN                    NaN
# 22536                        NaN                    NaN
# 22537                        NaN                    NaN
# 22538                        NaN                    NaN
# 22539                        NaN                    NaN
# 22540                        NaN                    NaN
# 22541                        NaN                    NaN
# 22542                        NaN                    NaN
# 22543                        NaN                    NaN
# 22544                        NaN                    NaN
# 22545                        NaN                    NaN
# 22546                        NaN                    NaN
# 22547                        NaN                    NaN
# 22548                        NaN                    NaN
# 22549                        NaN                    NaN
# 22550                        NaN                    NaN
# 22551                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 0                             10.0                    10.0
# 1                             10.0                    10.0
# 2                              9.0                    10.0
# 3                             10.0                     9.0
# 4                             10.0                    10.0
# 5                             10.0                    10.0
# 6                             10.0                     9.0
# 7                              NaN                     NaN
# 8                             10.0                     9.0
# 9                             10.0                    10.0
# 10                            10.0                    10.0
# 11                             8.0                    10.0
# 12                             9.0                     9.0
# 13                            10.0                    10.0
# 14                            10.0                    10.0
# 15                             9.0                     9.0
# 16                             9.0                    10.0
# 17                            10.0                    10.0
# 18                             9.0                    10.0
# 19                            10.0                     9.0
# 20                             9.0                     9.0
# 21                            10.0                    10.0
# 22                            10.0                    10.0
# 23                            10.0                    10.0
# 24                            10.0                    10.0
# 25                            10.0                     9.0
# 26                             NaN                     NaN
# 27                            10.0                     9.0
# 28                            10.0                     9.0
# 29                            10.0                    10.0
# ...                            ...                     ...
# 22522                          NaN                     NaN
# 22523                          NaN                     NaN
# 22524                          NaN                     NaN
# 22525                          NaN                     NaN
# 22526                          NaN                     NaN
# 22527                          NaN                     NaN
# 22528                          NaN                     NaN
# 22529                          NaN                     NaN
# 22530                          NaN                     NaN
# 22531                          NaN                     NaN
# 22532                          NaN                     NaN
# 22533                          NaN                     NaN
# 22534                          NaN                     NaN
# 22535                          NaN                     NaN
# 22536                          NaN                     NaN
# 22537                          NaN                     NaN
# 22538                          NaN                     NaN
# 22539                          NaN                     NaN
# 22540                          NaN                     NaN
# 22541                          NaN                     NaN
# 22542                          NaN                     NaN
# 22543                          NaN                     NaN
# 22544                          NaN                     NaN
# 22545                          NaN                     NaN
# 22546                          NaN                     NaN
# 22547                          NaN                     NaN
# 22548                          NaN                     NaN
# 22549                          NaN                     NaN
# 22550                          NaN                     NaN
# 22551                          NaN                     NaN
#
#        review_scores_value  jurisdiction_names  \
# 0                      9.0                 NaN
# 1                     10.0                 NaN
# 2                      9.0                 NaN
# 3                      9.0                 NaN
# 4                      9.0                 NaN
# 5                     10.0                 NaN
# 6                      9.0                 NaN
# 7                      NaN                 NaN
# 8                      9.0                 NaN
# 9                     10.0                 NaN
# 10                     9.0                 NaN
# 11                     9.0                 NaN
# 12                     9.0                 NaN
# 13                     9.0                 NaN
# 14                     9.0                 NaN
# 15                     9.0                 NaN
# 16                    10.0                 NaN
# 17                    10.0                 NaN
# 18                     9.0                 NaN
# 19                     9.0                 NaN
# 20                     9.0                 NaN
# 21                    10.0                 NaN
# 22                     9.0                 NaN
# 23                     9.0                 NaN
# 24                     9.0                 NaN
# 25                     9.0                 NaN
# 26                     NaN                 NaN
# 27                     9.0                 NaN
# 28                    10.0                 NaN
# 29                     9.0                 NaN
# ...                    ...                 ...
# 22522                  NaN                 NaN
# 22523                  NaN                 NaN
# 22524                  NaN                 NaN
# 22525                  NaN                 NaN
# 22526                  NaN                 NaN
# 22527                  NaN                 NaN
# 22528                  NaN                 NaN
# 22529                  NaN                 NaN
# 22530                  NaN                 NaN
# 22531                  NaN                 NaN
# 22532                  NaN                 NaN
# 22533                  NaN                 NaN
# 22534                  NaN                 NaN
# 22535                  NaN                 NaN
# 22536                  NaN                 NaN
# 22537                  NaN                 NaN
# 22538                  NaN                 NaN
# 22539                  NaN                 NaN
# 22540                  NaN                 NaN
# 22541                  NaN                 NaN
# 22542                  NaN                 NaN
# 22543                  NaN                 NaN
# 22544                  NaN                 NaN
# 22545                  NaN                 NaN
# 22546                  NaN                 NaN
# 22547                  NaN                 NaN
# 22548                  NaN                 NaN
# 22549                  NaN                 NaN
# 22550                  NaN                 NaN
# 22551                  NaN                 NaN
#
#        calculated_host_listings_count  reviews_per_month
# 0                                   4               3.76
# 1                                   1               1.42
# 2                                   1               1.25
# 3                                   1               0.39
# 4                                   1               1.75
# 5                                   1               0.15
# 6                                   3               0.23
# 7                                   1                NaN
# 8                                   2               0.47
# 9                                   1               2.83
# 10                                  1               2.10
# 11                                  1               0.75
# 12                                  2               0.61
# 13                                  2               0.59
# 14                                  1               2.27
# 15                                  1               0.94
# 16                                  2               0.18
# 17                                  2               0.05
# 18                                  1               1.63
# 19                                  3               0.29
# 20                                  1               0.33
# 21                                 10               0.02
# 22                                  3               0.70
# 23                                  4               2.42
# 24                                  1               4.94
# 25                                  1               1.44
# 26                                  1               0.01
# 27                                  2               1.63
# 28                                  1               0.21
# 29                                  2               3.04
# ...                               ...                ...
# 22522                               1                NaN
# 22523                               1                NaN
# 22524                               1                NaN
# 22525                               1                NaN
# 22526                               3                NaN
# 22527                               3                NaN
# 22528                               1                NaN
# 22529                               2                NaN
# 22530                               3                NaN
# 22531                               1                NaN
# 22532                               9                NaN
# 22533                               1                NaN
# 22534                               4                NaN
# 22535                               4                NaN
# 22536                               1               2.00
# 22537                               4                NaN
# 22538                               1                NaN
# 22539                               1                NaN
# 22540                               1                NaN
# 22541                               1                NaN
# 22542                               1                NaN
# 22543                               1                NaN
# 22544                               1                NaN
# 22545                               1                NaN
# 22546                               1                NaN
# 22547                               1                NaN
# 22548                               6                NaN
# 22549                               2                NaN
# 22550                               3                NaN
# 22551                               1                NaN
#
# [22552 rows x 29 columns]

# %%
copy_data[Cat]
# Out:
#        host_since                               host_location  \
# 0      18-08-2008        Key Biscayne, Florida, United States
# 1      16-09-2008                     Berlin, Berlin, Germany
# 2      19-10-2008        Coledale, New South Wales, Australia
# 3      07-11-2008                     Berlin, Berlin, Germany
# 4      16-05-2009                     Berlin, Berlin, Germany
# 5      25-08-2009                     Berlin, Berlin, Germany
# 6      18-11-2009                     Berlin, Berlin, Germany
# 7      03-12-2009                     Berlin, Berlin, Germany
# 8      20-12-2009       Santa Cruz, California, United States
# 9      04-01-2010                     Berlin, Berlin, Germany
# 10     08-01-2010      Rio de Janeiro, Rio de Janeiro, Brazil
# 11     18-01-2010                   Hamburg, Hamburg, Germany
# 12     20-12-2009       Santa Cruz, California, United States
# 13     27-02-2010                     Berlin, Berlin, Germany
# 14     02-03-2010                     Berlin, Berlin, Germany
# 15     17-03-2010                     Berlin, Berlin, Germany
# 16     27-03-2010                     Berlin, Berlin, Germany
# 17     27-03-2010                     Berlin, Berlin, Germany
# 18     23-04-2010                                     Namibia
# 19     18-11-2009                     Berlin, Berlin, Germany
# 20     10-05-2010                     Berlin, Berlin, Germany
# 21     22-02-2010                     Berlin, Berlin, Germany
# 22     14-11-2009                     Berlin, Berlin, Germany
# 23     05-04-2011                     Berlin, Berlin, Germany
# 24     30-05-2010                     Berlin, Berlin, Germany
# 25     12-06-2010                     Berlin, Berlin, Germany
# 26     27-06-2010                     Berlin, Berlin, Germany
# 27     02-07-2010                     Berlin, Berlin, Germany
# 28     06-07-2010                     Berlin, Berlin, Germany
# 29     21-06-2010                     Berlin, Berlin, Germany
# ...           ...                                         ...
# 22522  22-05-2017                     Berlin, Berlin, Germany
# 22523  19-08-2018                                          GB
# 22524  23-01-2012                     Berlin, Berlin, Germany
# 22525  09-08-2015                     Berlin, Berlin, Germany
# 22526  08-08-2017                     Berlin, Berlin, Germany
# 22527  08-08-2017                     Berlin, Berlin, Germany
# 22528  12-05-2013    Cologne, North Rhine-Westphalia, Germany
# 22529  08-06-2016  Gothenburg, Västra Götaland County, Sweden
# 22530  18-02-2013                     Berlin, Berlin, Germany
# 22531  19-09-2012                     Berlin, Berlin, Germany
# 22532  11-01-2014                     Berlin, Berlin, Germany
# 22533  16-02-2018                     Berlin, Berlin, Germany
# 22534  16-07-2018                                          DE
# 22535  16-07-2018                                          DE
# 22536  20-05-2011                     Munich, Bayern, Germany
# 22537  16-07-2018                                          DE
# 22538  04-05-2017                     Berlin, Berlin, Germany
# 22539  03-06-2012                     Berlin, Berlin, Germany
# 22540  21-01-2015                      London, United Kingdom
# 22541  05-09-2014                    Munich, Bavaria, Germany
# 22542  06-11-2018                     Berlin, Berlin, Germany
# 22543  17-02-2017                     Berlin, Berlin, Germany
# 22544  20-10-2013                     Berlin, Berlin, Germany
# 22545  02-01-2018                                          DE
# 22546  15-09-2014                   Hamburg, Hamburg, Germany
# 22547  02-08-2016                     Berlin, Berlin, Germany
# 22548  17-04-2016                     Berlin, Berlin, Germany
# 22549  03-08-2012                     Berlin, Berlin, Germany
# 22550  28-06-2015                     Berlin, Berlin, Germany
# 22551  09-03-2018                     Berlin, Berlin, Germany
#
#       host_neighbourhood                                 host_verifications  \
# 0                  Mitte  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 1        Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 2        Prenzlauer Berg  ['email', 'phone', 'facebook', 'reviews', 'man...
# 3             Schöneberg  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 4        Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 5        Prenzlauer Berg  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 6        Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 7         Friedrichshain  ['email', 'phone', 'facebook', 'jumio', 'offli...
# 8              Kreuzberg   ['email', 'phone', 'facebook', 'reviews', 'kba']
# 9        Prenzlauer Berg   ['email', 'phone', 'facebook', 'reviews', 'kba']
# 10            Copacabana  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 11       Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 12             Kreuzberg   ['email', 'phone', 'facebook', 'reviews', 'kba']
# 13             Kreuzberg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 14                 Mitte  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 15             Kreuzberg                      ['email', 'phone', 'reviews']
# 16       Prenzlauer Berg          ['email', 'phone', 'facebook', 'reviews']
# 17       Prenzlauer Berg          ['email', 'phone', 'facebook', 'reviews']
# 18       Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 19       Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 20        Friedrichshain                      ['email', 'phone', 'reviews']
# 21            Reuterkiez  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 22       Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 23       Prenzlauer Berg  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 24       Prenzlauer Berg  ['email', 'phone', 'facebook', 'reviews', 'sen...
# 25                Moabit  ['email', 'phone', 'facebook', 'reviews', 'man...
# 26       Prenzlauer Berg  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 27        Charlottenburg                      ['email', 'phone', 'reviews']
# 28            Schöneberg  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 29                 Mitte  ['phone', 'reviews', 'offline_government_id', ...
# ...                  ...                                                ...
# 22522                NaN  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 22523     Charlottenburg  ['email', 'phone', 'offline_government_id', 'g...
# 22524          Kreuzberg  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 22525                NaN       ['email', 'phone', 'jumio', 'government_id']
# 22526         Schöneberg                      ['email', 'phone', 'reviews']
# 22527         Schöneberg                      ['email', 'phone', 'reviews']
# 22528                NaN  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 22529           Neukölln  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 22530           Neukölln  ['email', 'phone', 'reviews', 'offline_governm...
# 22531              Mitte  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 22532    Friedrichsfelde                          ['email', 'phone', 'kba']
# 22533    Prenzlauer Berg  ['email', 'phone', 'jumio', 'offline_governmen...
# 22534             Pankow  ['email', 'phone', 'jumio', 'offline_governmen...
# 22535             Pankow  ['email', 'phone', 'jumio', 'offline_governmen...
# 22536          Neuhausen   ['email', 'phone', 'facebook', 'reviews', 'kba']
# 22537             Pankow  ['email', 'phone', 'jumio', 'offline_governmen...
# 22538                NaN  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 22539                NaN                      ['email', 'phone', 'reviews']
# 22540     Friedrichshain  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 22541                NaN  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 22542                NaN  ['email', 'phone', 'jumio', 'offline_governmen...
# 22543           Neukölln  ['email', 'phone', 'facebook', 'google', 'revi...
# 22544     Friedrichshain                                 ['email', 'phone']
# 22545     Friedrichshain                                 ['email', 'phone']
# 22546                NaN  ['email', 'phone', 'facebook', 'reviews', 'jum...
# 22547              Mitte                     ['email', 'phone', 'facebook']
# 22548    Prenzlauer Berg  ['email', 'phone', 'facebook', 'jumio', 'gover...
# 22549    Prenzlauer Berg  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 22550              Mitte                      ['email', 'phone', 'reviews']
# 22551           Neukölln                                 ['email', 'phone']
#
#       host_has_profile_pic host_identity_verified                   street  \
# 0                        t                      t  Berlin, Berlin, Germany
# 1                        t                      t  Berlin, Berlin, Germany
# 2                        t                      t  Berlin, Berlin, Germany
# 3                        t                      t  Berlin, Berlin, Germany
# 4                        t                      t  Berlin, Berlin, Germany
# 5                        t                      t  Berlin, Berlin, Germany
# 6                        t                      f  Berlin, Berlin, Germany
# 7                        t                      t  Berlin, Berlin, Germany
# 8                        t                      f  Berlin, Berlin, Germany
# 9                        t                      t  Berlin, Berlin, Germany
# 10                       t                      f          Berlin, Germany
# 11                       t                      f  Berlin, Berlin, Germany
# 12                       t                      f  Berlin, Berlin, Germany
# 13                       t                      t  Berlin, Berlin, Germany
# 14                       t                      f  Berlin, Berlin, Germany
# 15                       t                      f  Berlin, Berlin, Germany
# 16                       t                      f  Berlin, Berlin, Germany
# 17                       t                      f  Berlin, Berlin, Germany
# 18                       t                      f  Berlin, Berlin, Germany
# 19                       t                      f  Berlin, Berlin, Germany
# 20                       t                      f  Berlin, Berlin, Germany
# 21                       t                      t  Berlin, Berlin, Germany
# 22                       t                      t  Berlin, Berlin, Germany
# 23                       t                      t  Berlin, Berlin, Germany
# 24                       t                      t  Berlin, Berlin, Germany
# 25                       t                      t  Berlin, Berlin, Germany
# 26                       t                      t  Berlin, Berlin, Germany
# 27                       t                      f  Berlin, Berlin, Germany
# 28                       t                      f  Berlin, Berlin, Germany
# 29                       t                      f  Berlin, Berlin, Germany
# ...                    ...                    ...                      ...
# 22522                    t                      t  Berlin, Berlin, Germany
# 22523                    t                      f  Berlin, Berlin, Germany
# 22524                    t                      f  Berlin, Berlin, Germany
# 22525                    t                      f  Berlin, Berlin, Germany
# 22526                    t                      f  Berlin, Berlin, Germany
# 22527                    t                      f  Berlin, Berlin, Germany
# 22528                    t                      t  Berlin, Berlin, Germany
# 22529                    t                      t  Berlin, Berlin, Germany
# 22530                    t                      f  Berlin, Berlin, Germany
# 22531                    t                      t  Berlin, Berlin, Germany
# 22532                    t                      f  Berlin, Berlin, Germany
# 22533                    t                      f  Berlin, Berlin, Germany
# 22534                    t                      f  Berlin, Berlin, Germany
# 22535                    t                      f  Berlin, Berlin, Germany
# 22536                    t                      t  Berlin, Berlin, Germany
# 22537                    t                      f  Berlin, Berlin, Germany
# 22538                    t                      t  Berlin, Berlin, Germany
# 22539                    t                      f  Berlin, Berlin, Germany
# 22540                    t                      f  Berlin, Berlin, Germany
# 22541                    t                      t  Berlin, Berlin, Germany
# 22542                    t                      f  Berlin, Berlin, Germany
# 22543                    t                      t  Berlin, Berlin, Germany
# 22544                    t                      f  Berlin, Berlin, Germany
# 22545                    t                      f  Berlin, Berlin, Germany
# 22546                    t                      t  Berlin, Berlin, Germany
# 22547                    t                      f  Berlin, Berlin, Germany
# 22548                    t                      f  Berlin, Berlin, Germany
# 22549                    t                      t  Berlin, Berlin, Germany
# 22550                    t                      f  Berlin, Berlin, Germany
# 22551                    t                      f  Berlin, Berlin, Germany
#
#          neighbourhood    neighbourhood_cleansed neighbourhood_group_cleansed  \
# 0                Mitte           Brunnenstr. Süd                        Mitte
# 1                  NaN  Prenzlauer Berg Nordwest                       Pankow
# 2      Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 3           Schöneberg           Schöneberg-Nord       Tempelhof - Schöneberg
# 4      Prenzlauer Berg            Helmholtzplatz                       Pankow
# 5      Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 6      Prenzlauer Berg  Prenzlauer Berg Nordwest                       Pankow
# 7       Friedrichshain  Frankfurter Allee Süd FK     Friedrichshain-Kreuzberg
# 8            Kreuzberg     nördliche Luisenstadt     Friedrichshain-Kreuzberg
# 9      Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 10            Neukölln              Reuterstraße                     Neukölln
# 11     Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 12           Kreuzberg     nördliche Luisenstadt     Friedrichshain-Kreuzberg
# 13           Kreuzberg      südliche Luisenstadt     Friedrichshain-Kreuzberg
# 14               Mitte           Brunnenstr. Süd                        Mitte
# 15           Kreuzberg      Tempelhofer Vorstadt     Friedrichshain-Kreuzberg
# 16     Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 17                 NaN       Prenzlauer Berg Süd                       Pankow
# 18     Prenzlauer Berg            Helmholtzplatz                       Pankow
# 19     Prenzlauer Berg  Prenzlauer Berg Nordwest                       Pankow
# 20      Friedrichshain  Frankfurter Allee Süd FK     Friedrichshain-Kreuzberg
# 21            Neukölln              Reuterstraße                     Neukölln
# 22     Prenzlauer Berg            Helmholtzplatz                       Pankow
# 23     Prenzlauer Berg            Helmholtzplatz                       Pankow
# 24     Prenzlauer Berg            Helmholtzplatz                       Pankow
# 25              Moabit                Moabit Ost                        Mitte
# 26                 NaN      Prenzlauer Berg Nord                       Pankow
# 27      Charlottenburg           Otto-Suhr-Allee         Charlottenburg-Wilm.
# 28          Schöneberg           Schöneberg-Nord       Tempelhof - Schöneberg
# 29               Mitte           Brunnenstr. Süd                        Mitte
# ...                ...                       ...                          ...
# 22522      Wilmersdorf     Volkspark Wilmersdorf         Charlottenburg-Wilm.
# 22523   Charlottenburg           Otto-Suhr-Allee         Charlottenburg-Wilm.
# 22524        Kreuzberg     nördliche Luisenstadt     Friedrichshain-Kreuzberg
# 22525         Lankwitz                  Lankwitz        Steglitz - Zehlendorf
# 22526       Schöneberg           Schöneberg-Nord       Tempelhof - Schöneberg
# 22527       Schöneberg           Schöneberg-Nord       Tempelhof - Schöneberg
# 22528         Neukölln              Reuterstraße                     Neukölln
# 22529       Schöneberg            Schöneberg-Süd       Tempelhof - Schöneberg
# 22530         Neukölln              Reuterstraße                     Neukölln
# 22531            Mitte            Alexanderplatz                        Mitte
# 22532      Lichtenberg           Alt-Lichtenberg                  Lichtenberg
# 22533  Prenzlauer Berg       Prenzlauer Berg Ost                       Pankow
# 22534           Pankow                Pankow Süd                       Pankow
# 22535           Pankow                Pankow Süd                       Pankow
# 22536  Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 22537           Pankow                Pankow Süd                       Pankow
# 22538        Kreuzberg      südliche Luisenstadt     Friedrichshain-Kreuzberg
# 22539          Westend                   Westend         Charlottenburg-Wilm.
# 22540   Friedrichshain  Frankfurter Allee Süd FK     Friedrichshain-Kreuzberg
# 22541         Neukölln                   Rixdorf                     Neukölln
# 22542        Friedenau                 Friedenau       Tempelhof - Schöneberg
# 22543         Neukölln                   Rixdorf                     Neukölln
# 22544   Friedrichshain    Frankfurter Allee Nord     Friedrichshain-Kreuzberg
# 22545   Friedrichshain       Karl-Marx-Allee-Süd     Friedrichshain-Kreuzberg
# 22546       Schöneberg            Schöneberg-Süd       Tempelhof - Schöneberg
# 22547            Mitte           Brunnenstr. Süd                        Mitte
# 22548       Schöneberg           Schöneberg-Nord       Tempelhof - Schöneberg
# 22549  Prenzlauer Berg   Prenzlauer Berg Südwest                       Pankow
# 22550            Mitte            Alexanderplatz                        Mitte
# 22551         Neukölln         Schillerpromenade                     Neukölln
#
#        ... security_deposit cleaning_fee extra_people calendar_updated  \
# 0      ...            200.0         30.0         28.0     3 months ago
# 1      ...              0.0          0.0          0.0      7 weeks ago
# 2      ...            200.0         50.0         20.0       a week ago
# 3      ...            250.0         30.0         18.0      4 weeks ago
# 4      ...              0.0          0.0         24.0       3 days ago
# 5      ...            400.0         80.0         10.0      2 weeks ago
# 6      ...            500.0          0.0          0.0            today
# 7      ...              NaN          NaN         13.0            never
# 8      ...            500.0         50.0         20.0     2 months ago
# 9      ...              0.0         18.0         26.0       a week ago
# 10     ...              0.0         50.0         15.0       5 days ago
# 11     ...            500.0         49.0         24.0       2 days ago
# 12     ...            500.0         40.0         18.0     7 months ago
# 13     ...            300.0         50.0         25.0     2 months ago
# 14     ...            150.0         40.0         35.0       2 days ago
# 15     ...            500.0         50.0          0.0       2 days ago
# 16     ...            200.0         35.0          5.0       4 days ago
# 17     ...            200.0         55.0          5.0      4 weeks ago
# 18     ...            250.0         50.0         40.0      3 weeks ago
# 19     ...              NaN          NaN          0.0            today
# 20     ...            200.0         50.0         20.0            today
# 21     ...              NaN         30.0         10.0            today
# 22     ...              NaN         80.0          0.0     7 months ago
# 23     ...              NaN         40.0         20.0      2 weeks ago
# 24     ...            100.0         15.0         15.0       a week ago
# 25     ...              0.0         20.0          8.0       1 week ago
# 26     ...              NaN         50.0         10.0      4 weeks ago
# 27     ...            500.0          5.0         20.0       3 days ago
# 28     ...              0.0          0.0         15.0      3 weeks ago
# 29     ...            100.0         30.0         12.0      2 weeks ago
# ...    ...              ...          ...          ...              ...
# 22522  ...              0.0         30.0         36.0            today
# 22523  ...            150.0         30.0          0.0        yesterday
# 22524  ...            200.0         25.0         10.0            today
# 22525  ...              NaN          NaN          0.0        yesterday
# 22526  ...              0.0          0.0          0.0        yesterday
# 22527  ...              0.0         49.0          0.0        yesterday
# 22528  ...              NaN          NaN          0.0        yesterday
# 22529  ...              NaN          NaN          0.0        yesterday
# 22530  ...              0.0         60.0         15.0            today
# 22531  ...              NaN          NaN          0.0        yesterday
# 22532  ...              NaN        299.0          0.0            today
# 22533  ...              NaN          NaN          0.0        yesterday
# 22534  ...              NaN          NaN          0.0        yesterday
# 22535  ...              NaN          NaN          0.0        yesterday
# 22536  ...              NaN          NaN          0.0        yesterday
# 22537  ...              NaN          NaN          0.0        yesterday
# 22538  ...              NaN          NaN          0.0        yesterday
# 22539  ...              NaN          NaN          0.0        yesterday
# 22540  ...              NaN          NaN          0.0        yesterday
# 22541  ...              0.0          0.0         10.0        yesterday
# 22542  ...              NaN          NaN          0.0        yesterday
# 22543  ...              NaN          NaN          0.0            today
# 22544  ...            100.0         20.0          0.0            today
# 22545  ...              0.0         10.0         10.0            today
# 22546  ...              NaN        100.0          0.0            today
# 22547  ...              NaN          NaN          0.0            today
# 22548  ...              0.0          0.0         10.0            today
# 22549  ...              NaN          NaN          0.0            today
# 22550  ...              NaN          NaN          0.0            today
# 22551  ...              NaN          NaN          0.0            today
#
#       requires_license instant_bookable is_business_travel_ready  \
# 0                    t                f                        f
# 1                    t                f                        f
# 2                    t                t                        f
# 3                    t                f                        f
# 4                    t                f                        f
# 5                    t                f                        f
# 6                    t                f                        f
# 7                    t                f                        f
# 8                    t                f                        f
# 9                    t                f                        f
# 10                   t                f                        f
# 11                   t                f                        f
# 12                   t                f                        f
# 13                   t                f                        f
# 14                   t                f                        f
# 15                   t                f                        f
# 16                   t                f                        f
# 17                   t                f                        f
# 18                   t                t                        f
# 19                   t                f                        f
# 20                   t                f                        f
# 21                   t                f                        f
# 22                   t                f                        f
# 23                   t                t                        f
# 24                   t                f                        f
# 25                   t                t                        f
# 26                   t                t                        f
# 27                   t                f                        f
# 28                   t                f                        f
# 29                   t                f                        f
# ...                ...              ...                      ...
# 22522                t                t                        f
# 22523                t                f                        f
# 22524                t                f                        f
# 22525                t                f                        f
# 22526                t                f                        f
# 22527                t                f                        f
# 22528                t                f                        f
# 22529                t                f                        f
# 22530                t                f                        f
# 22531                t                f                        f
# 22532                t                f                        f
# 22533                t                f                        f
# 22534                t                f                        f
# 22535                t                f                        f
# 22536                t                t                        f
# 22537                t                f                        f
# 22538                t                t                        f
# 22539                t                f                        f
# 22540                t                f                        f
# 22541                t                t                        f
# 22542                t                t                        f
# 22543                t                f                        f
# 22544                t                t                        f
# 22545                t                t                        f
# 22546                t                t                        f
# 22547                t                f                        f
# 22548                t                t                        f
# 22549                t                f                        f
# 22550                t                f                        f
# 22551                t                f                        f
#
#                cancellation_policy require_guest_profile_picture  \
# 0      strict_14_with_grace_period                             f
# 1                         flexible                             f
# 2      strict_14_with_grace_period                             f
# 3      strict_14_with_grace_period                             f
# 4                         moderate                             f
# 5      strict_14_with_grace_period                             f
# 6      strict_14_with_grace_period                             f
# 7      strict_14_with_grace_period                             f
# 8      strict_14_with_grace_period                             f
# 9      strict_14_with_grace_period                             f
# 10     strict_14_with_grace_period                             f
# 11     strict_14_with_grace_period                             f
# 12     strict_14_with_grace_period                             f
# 13     strict_14_with_grace_period                             f
# 14     strict_14_with_grace_period                             f
# 15     strict_14_with_grace_period                             f
# 16     strict_14_with_grace_period                             f
# 17     strict_14_with_grace_period                             f
# 18     strict_14_with_grace_period                             f
# 19     strict_14_with_grace_period                             f
# 20     strict_14_with_grace_period                             t
# 21                        flexible                             f
# 22     strict_14_with_grace_period                             f
# 23     strict_14_with_grace_period                             f
# 24                        moderate                             f
# 25     strict_14_with_grace_period                             f
# 26     strict_14_with_grace_period                             f
# 27                        flexible                             t
# 28     strict_14_with_grace_period                             f
# 29     strict_14_with_grace_period                             f
# ...                            ...                           ...
# 22522                     moderate                             f
# 22523  strict_14_with_grace_period                             f
# 22524  strict_14_with_grace_period                             f
# 22525                     flexible                             f
# 22526  strict_14_with_grace_period                             f
# 22527  strict_14_with_grace_period                             f
# 22528                     flexible                             f
# 22529                     flexible                             f
# 22530                     flexible                             f
# 22531  strict_14_with_grace_period                             f
# 22532  strict_14_with_grace_period                             f
# 22533                     flexible                             f
# 22534  strict_14_with_grace_period                             f
# 22535  strict_14_with_grace_period                             f
# 22536                     flexible                             f
# 22537  strict_14_with_grace_period                             f
# 22538                     flexible                             f
# 22539                     flexible                             f
# 22540                     flexible                             f
# 22541                     flexible                             f
# 22542                     flexible                             f
# 22543                     flexible                             f
# 22544                     flexible                             f
# 22545                     moderate                             f
# 22546  strict_14_with_grace_period                             f
# 22547                     flexible                             f
# 22548                     flexible                             f
# 22549                     flexible                             f
# 22550                     flexible                             f
# 22551                     flexible                             f
#
#       require_guest_phone_verification
# 0                                    f
# 1                                    f
# 2                                    f
# 3                                    f
# 4                                    f
# 5                                    f
# 6                                    f
# 7                                    f
# 8                                    t
# 9                                    f
# 10                                   f
# 11                                   f
# 12                                   t
# 13                                   f
# 14                                   f
# 15                                   f
# 16                                   f
# 17                                   f
# 18                                   f
# 19                                   f
# 20                                   t
# 21                                   t
# 22                                   f
# 23                                   f
# 24                                   f
# 25                                   f
# 26                                   f
# 27                                   t
# 28                                   f
# 29                                   f
# ...                                ...
# 22522                                f
# 22523                                f
# 22524                                f
# 22525                                f
# 22526                                f
# 22527                                f
# 22528                                f
# 22529                                f
# 22530                                f
# 22531                                f
# 22532                                f
# 22533                                f
# 22534                                f
# 22535                                f
# 22536                                f
# 22537                                f
# 22538                                f
# 22539                                f
# 22540                                f
# 22541                                f
# 22542                                f
# 22543                                f
# 22544                                f
# 22545                                f
# 22546                                f
# 22547                                f
# 22548                                f
# 22549                                f
# 22550                                f
# 22551                                f
#
# [22552 rows x 31 columns]

# %% [markdown]
# ***

# %% [markdown]
# #### Null Value Treatment

# %% [raw]
# Central Tendency = Mean, Meadian & Mode

# %%
for i in Num:
    copy_data[i] = copy_data[i].fillna(copy_data[i].median())

# %%
copy_data[Num].isnull().sum()
# Out:
# host_listings_count               0
# host_total_listings_count         0
# latitude                          0
# longitude                         0
# accommodates                      0
# bathrooms                         0
# bedrooms                          0
# beds                              0
# guests_included                   0
# minimum_nights                    0
# maximum_nights                    0
# availability_30                   0
# availability_60                   0
# availability_90                   0
# availability_365                  0
# number_of_reviews                 0
# first_review                      0
# last_review                       0
# review_scores_rating              0
# review_scores_accuracy            0
# review_scores_cleanliness         0
# review_scores_checkin             0
# review_scores_communication       0
# review_scores_location            0
# review_scores_value               0
# calculated_host_listings_count    0
# reviews_per_month                 0
# dtype: int64

# %%
# copy_data.drop(['host_acceptance_rate', 'jurisdiction_names'], axis=1, inplace=True)
Num = [col for col in Num if col not in ['host_acceptance_rate', 'jurisdiction_names']]

# %%
copy_data[Cat].isnull().sum()
# Out:
# host_since                            26
# host_location                        116
# host_neighbourhood                  5094
# host_verifications                    26
# host_has_profile_pic                  26
# host_identity_verified                26
# street                                 0
# neighbourhood                       1131
# neighbourhood_cleansed                 0
# neighbourhood_group_cleansed           0
# city                                   5
# state                                 84
# zipcode                              656
# market                                63
# smart_location                         0
# is_location_exact                      0
# property_type                          0
# room_type                              0
# bed_type                               0
# amenities                              0
# price                                 41
# security_deposit                    9899
# cleaning_fee                        7147
# extra_people                           0
# calendar_updated                       0
# requires_license                       0
# instant_bookable                       0
# is_business_travel_ready               0
# cancellation_policy                    0
# require_guest_profile_picture          0
# require_guest_phone_verification       0
# dtype: int64

# %%
for i in Cat:
    copy_data[i] = copy_data[i].fillna(copy_data[i].mode())

# %%
copy_data[Cat].isnull().sum()
# Out:
# host_since                          0
# host_location                       0
# host_neighbourhood                  0
# host_verifications                  0
# host_has_profile_pic                0
# host_identity_verified              0
# street                              0
# neighbourhood                       0
# neighbourhood_cleansed              0
# neighbourhood_group_cleansed        0
# city                                0
# state                               0
# zipcode                             0
# market                              0
# smart_location                      0
# is_location_exact                   0
# property_type                       0
# room_type                           0
# bed_type                            0
# amenities                           0
# price                               0
# security_deposit                    0
# cleaning_fee                        0
# extra_people                        0
# calendar_updated                    0
# requires_license                    0
# instant_bookable                    0
# is_business_travel_ready            0
# cancellation_policy                 0
# require_guest_profile_picture       0
# require_guest_phone_verification    0
# dtype: int64

# %% [markdown]
# ***

# %% [markdown]
# Working on new dataset

# %% [markdown]
# ## Univariate Analysis

# %%
data = pd.read_csv("Downloads/US_Heart_Patients_2.csv")

# %%
data.head(3)
# Out:
#    Gender   age  education  currentSmoker  cigsPerDay  BP Meds  \
# 0    Male  39.0        4.0            0.0         0.0      0.0
# 1  Female  46.0        2.0            0.0         0.0      0.0
# 2    Male  48.0        1.0            1.0        20.0      0.0
#
#    prevalentStroke  prevalentHyp  diabetes  tot cholesterol  ...    BMI  \
# 0              0.0           0.0       0.0            195.0  ...  26.97
# 1              0.0           0.0       0.0            250.0  ...  28.73
# 2              0.0           0.0       0.0            245.0  ...  25.34
#
#    heartRate  glucose  Heart-Att  Unnamed: 16  Unnamed: 17  Unnamed: 18  \
# 0       80.0     77.0          0          NaN          NaN          NaN
# 1       95.0     76.0          0          NaN          NaN          NaN
# 2       75.0     70.0          0          NaN          NaN          NaN
#
#    Unnamed: 19  Unnamed: 20  Unnamed: 21
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
#
# [3 rows x 22 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4240 entries, 0 to 4239
# Data columns (total 22 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Gender           4232 non-null   object
#  1   age              4238 non-null   float64
#  2   education        4130 non-null   float64
#  3   currentSmoker    4237 non-null   float64
#  4   cigsPerDay       4209 non-null   float64
#  5   BP Meds          4180 non-null   float64
#  6   prevalentStroke  4231 non-null   float64
#  7   prevalentHyp     4238 non-null   float64
#  8   diabetes         4238 non-null   float64
#  9   tot cholesterol  4180 non-null   float64
#  10  Systolic BP      4236 non-null   float64
#  11  Diastolic BP     4235 non-null   float64
#  12  BMI              4216 non-null   float64
#  13  heartRate        4236 non-null   float64
#  14  glucose          3849 non-null   float64
#  15  Heart-Att        4240 non-null   int64
#  16  Unnamed: 16      0 non-null      float64
#  17  Unnamed: 17      0 non-null      float64
#  18  Unnamed: 18      0 non-null      float64
#  19  Unnamed: 19      0 non-null      float64
#  20  Unnamed: 20      0 non-null      float64
#  21  Unnamed: 21      0 non-null      float64
# dtypes: float64(20), int64(1), object(1)
# memory usage: 728.9+ KB

# %% [markdown]
# #### Null Value Treatment

# %%
data.isnull().sum()
# Out:
# Gender                8
# age                   2
# education           110
# currentSmoker         3
# cigsPerDay           31
# BP Meds              60
# prevalentStroke       9
# prevalentHyp          2
# diabetes              2
# tot cholesterol      60
# Systolic BP           4
# Diastolic BP          5
# BMI                  24
# heartRate             4
# glucose             391
# Heart-Att             0
# Unnamed: 16        4240
# Unnamed: 17        4240
# Unnamed: 18        4240
# Unnamed: 19        4240
# Unnamed: 20        4240
# Unnamed: 21        4240
# dtype: int64

# %%
Num = []
Cat = []

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        Cat.append(col)
    else:
        Num.append(col)

# %%
Num
# Out:
# ['age',
#  'education',
#  'currentSmoker',
#  'cigsPerDay',
#  'BP Meds',
#  'prevalentStroke',
#  'prevalentHyp',
#  'diabetes',
#  'tot cholesterol',
#  'Systolic BP',
#  'Diastolic BP',
#  'BMI',
#  'heartRate',
#  'glucose',
#  'Heart-Att']

# %%
Cat
# Out:
# ['Gender']

# %%
len(Num)
# Out:
# 15

# %%
data.shape
# Out:
# (4240, 16)

# %%
for i in Cat:
    data[i] = data[i].fillna(data[i].mode()[0])

# %%
for i in Num:
    data[i] = data[i].fillna(data[i].median())

# %%
data.isnull().sum()
# Out:
# Gender             0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BP Meds            0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# tot cholesterol    0
# Systolic BP        0
# Diastolic BP       0
# BMI                0
# heartRate          0
# glucose            0
# Heart-Att          0
# dtype: int64

# %%
data.dropna(axis=1, inplace=True)  # deleting cols having NaN values

# %%
data.isnull().sum()
# Out:
# Gender             0
# age                0
# education          0
# currentSmoker      0
# cigsPerDay         0
# BP Meds            0
# prevalentStroke    0
# prevalentHyp       0
# diabetes           0
# tot cholesterol    0
# Systolic BP        0
# Diastolic BP       0
# BMI                0
# heartRate          0
# glucose            0
# Heart-Att          0
# dtype: int64

# %%
data.shape
# Out:
# (4240, 16)

# %%
(data['Heart-Att'] == 1).sum()
# Out:
# 644

# %%
sns.countplot(data = data, x = 'education')
# Out:
# <Axes: xlabel='education', ylabel='count'>

# %%
sns.countplot(data = data, x = 'Heart-Att')
# Out:
# <Axes: xlabel='Heart-Att', ylabel='count'>

# %%
sns.countplot(data = data, x = 'Heart-Att');
plt.title('# Heart-Att counts');
plt.xlabel("Patient Heart-Attack Types");
plt.ylabel("No. of Patients");

# %%
sns.countplot(data = data, x = 'Gender');
plt.title('# Genderwise Data');
plt.xlabel("Gender");
plt.ylabel("No. of Patients");

# %%
data.columns
# Out:
# Index(['Gender', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BP Meds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'tot cholesterol',
#        'Systolic BP', 'Diastolic BP', 'BMI', 'heartRate', 'glucose',
#        'Heart-Att'],
#       dtype='object')

# %%
list = ['education', 'currentSmoker', 'BP Meds', 'prevalentStroke', 'prevalentHyp', 'diabetes']

# %%
plt.figure(figsize = (12, 6))
for i in list:
    sns.countplot(data = data, x = i, color = 'yellow');
    plt.show()
    # plt.title(i, "Data);
    # plt.xlabel("Gender");
    # plt.ylabel("No. of Patients");

# %%
Num
# Out:
# ['age',
#  'education',
#  'currentSmoker',
#  'cigsPerDay',
#  'BP Meds',
#  'prevalentStroke',
#  'prevalentHyp',
#  'diabetes',
#  'tot cholesterol',
#  'Systolic BP',
#  'Diastolic BP',
#  'BMI',
#  'heartRate',
#  'glucose',
#  'Heart-Att']

# %%
Num = ['age', 'cigsPerDay', 'tot cholesterol',
       'Systolic BP', 'Diastolic BP', 'BMI', 'heartRate', 'glucose',]

# %%
plt.figure(figsize = (12, 6))
for i in Num:
    sns.boxplot(data[i], orient ='h'); #orientation = horizontal(h) or vertical(v)
    plt.show()
